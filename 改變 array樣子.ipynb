# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
a= np.random.randn(100)

# %%
a.shape=(5,20)

# %%
a
# Out:
# array([[-3.73765354e-01,  1.05698768e+00,  5.86915339e-01,
#          9.44868777e-01,  3.09055031e-01, -1.55483254e+00,
#         -2.04390500e-01, -7.53515384e-01,  2.38428975e-01,
#          2.35027311e-01, -2.16437252e-01, -1.35859490e+00,
#         -1.80964234e-01,  1.29914257e+00,  4.49521401e-01,
#         -5.81343272e-01,  3.11215166e-01, -2.86602987e-01,
#          1.60195321e+00, -8.21972098e-01],
#        [ 1.49734860e+00,  1.47950617e+00, -3.26857377e-01,
#          1.70663665e+00,  2.15200349e-01,  1.17545776e-03,
#          8.24986590e-01,  6.43983433e-01,  1.37059151e-01,
#          8.57608883e-01,  5.65395497e-01, -1.32757121e+00,
#         -9.25688784e-01, -1.96556679e-01, -1.10232015e-01,
#         -7.27158973e-01,  2.34800229e+00,  1.51389476e+00,
#          4.14476457e-01, -8.34832670e-01],
#        [-4.84459317e-01,  1.76577639e+00, -1.16069246e+00,
#          5.22344056e-01,  3.04824220e-01,  2.89049626e-01,
# ...

# %%
plt.plot(a)

# %%
plt.plot(a*10+50)

# %%
a.shape=(20,5)

# %%
a.reshape(100,1)
# Out:
# array([[-3.73765354e-01],
#        [ 1.05698768e+00],
#        [ 5.86915339e-01],
#        [ 9.44868777e-01],
#        [ 3.09055031e-01],
#        [-1.55483254e+00],
#        [-2.04390500e-01],
#        [-7.53515384e-01],
#        [ 2.38428975e-01],
#        [ 2.35027311e-01],
#        [-2.16437252e-01],
#        [-1.35859490e+00],
#        [-1.80964234e-01],
#        [ 1.29914257e+00],
#        [ 4.49521401e-01],
#        [-5.81343272e-01],
#        [ 3.11215166e-01],
#        [-2.86602987e-01],
#        [ 1.60195321e+00],
#        [-8.21972098e-01],
#        [ 1.49734860e+00],
#        [ 1.47950617e+00],
#        [-3.26857377e-01],
#        [ 1.70663665e+00],
#        [ 2.15200349e-01],
#        [ 1.17545776e-03],
#        [ 8.24986590e-01],
#        [ 6.43983433e-01],
#        [ 1.37059151e-01],
#        [ 8.57608883e-01],
#        [ 5.65395497e-01],
#        [-1.32757121e+00],
#        [-9.25688784e-01],
#        [-1.96556679e-01],
#        [-1.10232015e-01],
# ...

# %%
a
# Out:
# array([[-3.73765354e-01,  1.05698768e+00,  5.86915339e-01,
#          9.44868777e-01,  3.09055031e-01],
#        [-1.55483254e+00, -2.04390500e-01, -7.53515384e-01,
#          2.38428975e-01,  2.35027311e-01],
#        [-2.16437252e-01, -1.35859490e+00, -1.80964234e-01,
#          1.29914257e+00,  4.49521401e-01],
#        [-5.81343272e-01,  3.11215166e-01, -2.86602987e-01,
#          1.60195321e+00, -8.21972098e-01],
#        [ 1.49734860e+00,  1.47950617e+00, -3.26857377e-01,
#          1.70663665e+00,  2.15200349e-01],
#        [ 1.17545776e-03,  8.24986590e-01,  6.43983433e-01,
#          1.37059151e-01,  8.57608883e-01],
#        [ 5.65395497e-01, -1.32757121e+00, -9.25688784e-01,
#         -1.96556679e-01, -1.10232015e-01],
#        [-7.27158973e-01,  2.34800229e+00,  1.51389476e+00,
#          4.14476457e-01, -8.34832670e-01],
#        [-4.84459317e-01,  1.76577639e+00, -1.16069246e+00,
#          5.22344056e-01,  3.04824220e-01],
# ...

# %%
a.shape=(50,2)

# %%
plt.plot(a)

# %%
a=np.linspace(1.,10.,15)
b=np.linspace(1.,10.,15)
plt.scatter(a,b)
